# %%
import pandas as pd
from pandarallel import pandarallel
pandarallel.initialize()
pd.set_option('max_colwidth', 140)
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
data = pd.read_csv("kata/emotionData.csv")
data = data[data.label != 'anger']

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.groupby('label')['tweet'].nunique()
# Out:
# label
# fear        646
# happy      1012
# love        636
# sadness     996
# Name: tweet, dtype: int64

# %%
data
# Out:
#         label  \
# 0       happy
# 1       happy
# 2       happy
# 3     sadness
# 4     sadness
# ...       ...
# 3295  sadness
# 3296     love
# 3297     fear
# 3298    happy
# 3299  sadness
#
#                                                                                                                                             tweet
# 0                            Kepingin gudeg mbarek Bu hj. Amad Foto dari google, sengaja, biar teman-teman jg membayangkannya. Berbagi itu indah.
# 1     Sharing pengalaman aja, kemarin jam 18.00 batalin tiket di stasiun pasar senen, lancar, antrian tidak terlalu rame,15 menitan dan beress...
# 2     Sharing sama temen tuh emg guna bgt. Disaat lu ngerasa masalah lu berat bgt ternyata temen kita sendiri punya masalah lebih berat dr kit...
# 3     Orang lain kalau pake ponco itu buat jas hujan, nah dia pake buat kasur. Ya tadi gara2 saking gak punya apa2. Mamak bilang, kami tuh di ...
# 4     Pulang udah H-4 lebaran dilema sekali. Seperti tidak bisa melakukan apa2 dirumah sebelum lebaran. Buka puasa bareng cuman 3 hari sama ke...
# ...                                                                                                                                           ...
# 3295                                                           nah diam lebih bagus yaudah saya diam saja deh -_- kepo deh memang tadi kemna haha
# 3296  Tahukah kamu, bahwa saat itu papa memejamkan matanya dan menahan gejolak dan batinnya. Bahwa papa sangat ingin mengikuti keinginanmu tap...
# 3297  Sulitnya menetapkan Calon Wapresnya Jokowi di Pilpres 2019 salah satunya disebabkan gemuknya partai koalisi yang mengusung petahana. Seh...
# 3298  [USERNAME] dulu beneran ada mahasiswa Teknik UI nembak pacarnya pas sahur di Kukusan Teknik Depok, diliput kru Katakan Cinta (dan belum ...
# 3299                                                       Ya Allah, hanya Engkau yang mengetahui rasa sakit di hati ini. Sembuhkanlah Ya Allah..
#
# [3300 rows x 2 columns]

# %%
idiom = pd.read_csv("kata/idioms_id.txt", sep=":")
idiom
# Out:
#                idiom  score
# 0      acungi jempol      5
# 1          anak alay     -4
# 2          anak emas      4
# 3     banting tulang      2
# 4        banyak akal      4
# ..               ...    ...
# 87      terima kasih      4
# 88       tinggi hati     -4
# 89  tuhan memberkati      5
# 90       tukang tipu     -5
# 91      turun tangan      3
#
# [92 rows x 2 columns]

# %%
emoticon = pd.read_csv("kata/emoticon_id.txt", sep='\s\|\s', engine='python')
emoticon
# Out:
#     emot  score
# 0    ^^v      4
# 1    ^_^      4
# 2     xp     -4
# 3    ^^V      4
# 4     xd      2
# ..   ...    ...
# 624  x-(     -4
# 625   xd      2
# 626   xo      2
# 627   xp     -4
# 628  }:)     -4
#
# [629 rows x 2 columns]

# %%
kata = pd.read_csv("kata/sentiWord.txt", sep=":")
kata
# Out:
#          word  score
# 0       abadi      5
# 1       absen     -3
# 2     abu-abu     -1
# 3        acuh      4
# 4        adil      5
# ...       ...    ...
# 1724      wow      4
# 1725      wtf     -4
# 1726    yatim     -1
# 1727     yeah      3
# 1728     zina     -5
#
# [1729 rows x 2 columns]

# %%
akronim = pd.read_csv("kata/akronim.csv", usecols=['slang', 'formal'])
akronim
# Out:
#           slang         formal
# 0          woww            wow
# 1         aminn           amin
# 2           met        selamat
# 3        netaas        menetas
# 4       keberpa       keberapa
# ...         ...            ...
# 15001  gataunya  enggak taunya
# 15002      gtau     enggak tau
# 15003     gatau     enggak tau
# 15004     fans2        fan-fan
# 15005   gaharus   enggak harus
#
# [15006 rows x 2 columns]

# %%
stoplist = pd.read_csv("kata/stoplist.txt")
stoplist
# Out:
#        word
# 0       ada
# 1    adalah
# 2    adanya
# 3    adapun
# 4      agak
# ..      ...
# 753    wong
# 754   yaitu
# 755   yakin
# 756   yakni
# 757    yang
#
# [758 rows x 1 columns]

# %%
negasi = pd.read_csv("kata/negatingword.txt")
negasi
# Out:
#            word
# 0         belum
# 1         bukan
# 2           tak
# 3         tanpa
# 4         tidak
# 5       pantang
# 6        jangan
# 7      bukanlah
# 8           sok
# 9  tidak pernah

# %%
def anything_to_sentiment(anything):
    if type(anything) == str:
        if anything in ['love', 'happy']:
            return 'pos'
        elif anything in ['fear', 'sadness']:
            return 'neg'
    elif type(anything) == int:
        if anything > 0:
            return 'pos'
        elif anything < 0:
            return 'neg'

# %%
data['sentiment'] = data['label'].astype(str).apply(anything_to_sentiment)
data.to_csv('sentimentedKata/tweetSent.csv', index=False)
data
# Out:
#         label  \
# 0       happy
# 1       happy
# 2       happy
# 3     sadness
# 4     sadness
# ...       ...
# 3295  sadness
# 3296     love
# 3297     fear
# 3298    happy
# 3299  sadness
#
#                                                                                                                                             tweet  \
# 0                            Kepingin gudeg mbarek Bu hj. Amad Foto dari google, sengaja, biar teman-teman jg membayangkannya. Berbagi itu indah.
# 1     Sharing pengalaman aja, kemarin jam 18.00 batalin tiket di stasiun pasar senen, lancar, antrian tidak terlalu rame,15 menitan dan beress...
# 2     Sharing sama temen tuh emg guna bgt. Disaat lu ngerasa masalah lu berat bgt ternyata temen kita sendiri punya masalah lebih berat dr kit...
# 3     Orang lain kalau pake ponco itu buat jas hujan, nah dia pake buat kasur. Ya tadi gara2 saking gak punya apa2. Mamak bilang, kami tuh di ...
# 4     Pulang udah H-4 lebaran dilema sekali. Seperti tidak bisa melakukan apa2 dirumah sebelum lebaran. Buka puasa bareng cuman 3 hari sama ke...
# ...                                                                                                                                           ...
# 3295                                                           nah diam lebih bagus yaudah saya diam saja deh -_- kepo deh memang tadi kemna haha
# 3296  Tahukah kamu, bahwa saat itu papa memejamkan matanya dan menahan gejolak dan batinnya. Bahwa papa sangat ingin mengikuti keinginanmu tap...
# 3297  Sulitnya menetapkan Calon Wapresnya Jokowi di Pilpres 2019 salah satunya disebabkan gemuknya partai koalisi yang mengusung petahana. Seh...
# 3298  [USERNAME] dulu beneran ada mahasiswa Teknik UI nembak pacarnya pas sahur di Kukusan Teknik Depok, diliput kru Katakan Cinta (dan belum ...
# 3299                                                       Ya Allah, hanya Engkau yang mengetahui rasa sakit di hati ini. Sembuhkanlah Ya Allah..
#
#      sentiment
# 0          pos
# 1          pos
# 2          pos
# 3          neg
# 4          neg
# ...        ...
# 3295       neg
# 3296       pos
# 3297       neg
# 3298       pos
# 3299       neg
#
# [3300 rows x 3 columns]

# %%
idiom['sentiment'] = idiom['score'].astype(int).apply(anything_to_sentiment)
idiom.to_csv('sentimentedKata/idiom.csv', index=False)
idiom.groupby('sentiment')['idiom'].nunique()
# Out:
# sentiment
# neg    49
# pos    43
# Name: idiom, dtype: int64

# %%
emoticon['sentiment'] = emoticon['score'].astype(int).apply(anything_to_sentiment)
emoticon.to_csv('sentimentedKata/emoticon.csv', index=False)
emoticon.groupby('sentiment')['emot'].nunique()
# Out:
# sentiment
# neg    52
# pos    45
# Name: emot, dtype: int64

# %%
kata['sentiment'] = kata['score'].astype(int).apply(anything_to_sentiment)
kata.to_csv('sentimentedKata/kata.csv', index=False)
kata.groupby('sentiment')['word'].nunique()
# Out:
# sentiment
# neg    1212
# pos     517
# Name: word, dtype: int64

# %%
kamusAlay = dict(zip(akronim.slang, akronim.formal))
punct = '!"#$%&\'()*+,-./:;<=>?@\\^_`{|}~'

def slang_to_formal(tweet):
    tweet = tweet.translate(str.maketrans(punct, len(punct)*" "))
    slang = tweet.split()
    formal = []
    for word in slang:
        if not word.isdigit():
            if word in kamusAlay:
                formal.extend(kamusAlay[word].split())
            else:
                formal.append(word)
    return " ".join(formal)

# %%
import re


def make_pattern(text):
    pattern = "|".join(map(re.escape, text))
    pattern = ["(?<=\s)(" + pattern + ")(?=\s)",
               "(?<=\s)(" + pattern + ")",
               "(" + pattern + ")(?=\s)"]
    return re.compile("|".join(pattern))


bannedWord = ['covid', 'corona', 'virus', 'coronavirus', 'amp']
stop = make_pattern(stoplist.word.to_list() + bannedWord)
neg_emot = make_pattern(emoticon.emot[emoticon.sentiment == 'neg'][::-1])
pos_emot = make_pattern(emoticon.emot[emoticon.sentiment == 'pos'][::-1])
negate = make_pattern(negasi.word.to_list())
url = re.compile(r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?\xab\xbb\u201c\u201d\u2018\u2019]))')
username = "@\w{1,}"
hashtag = "#\w{1,}"
tags = ['[neg]', '[pos]', '[url]', '[username]', '[not]']
patterns = [neg_emot, pos_emot, url, username, hashtag, negate, stop]
# database = dict(zip(tags, patterns))


def replace_with_tag(tweet):
    tweet = tweet.lower()
#     tweet = ' '.join(word_tokenize(tweet))
    tweet = re.sub(url, ' [url] ', tweet)
    tweet = re.sub(username, ' [username] ', tweet)
    tweet = re.sub(hashtag, ' ', tweet)
    tweet = re.sub(neg_emot, ' [neg] ', tweet)
    tweet = re.sub(pos_emot, ' [pos] ', tweet)
    tweet = slang_to_formal(tweet)
    tweet = re.sub(negate, ' [not] ', tweet)
#     tweet = re.sub(stop, ' ', tweet)
    tweet = re.sub(' +', ' ', tweet)
    return tweet

# %%
data1 = pd.read_csv('sentimentedKata/tweetSent.csv')

dataCleaned
dataCleaned.drop_duplicates(subset='tweet', keep='first', inplace=True)
dataCleaned.reset_index(drop=True, inplace=True)
dataCleaned
# Out:
#         label  \
# 0       happy
# 1       happy
# 2       happy
# 3     sadness
# 4     sadness
# ...       ...
# 3284  sadness
# 3285     love
# 3286     fear
# 3287    happy
# 3288  sadness
#
#                                                                                                                                             tweet  \
# 0                            Kepingin gudeg mbarek Bu hj. Amad Foto dari google, sengaja, biar teman-teman jg membayangkannya. Berbagi itu indah.
# 1     Sharing pengalaman aja, kemarin jam 18.00 batalin tiket di stasiun pasar senen, lancar, antrian tidak terlalu rame,15 menitan dan beress...
# 2     Sharing sama temen tuh emg guna bgt. Disaat lu ngerasa masalah lu berat bgt ternyata temen kita sendiri punya masalah lebih berat dr kit...
# 3     Orang lain kalau pake ponco itu buat jas hujan, nah dia pake buat kasur. Ya tadi gara2 saking gak punya apa2. Mamak bilang, kami tuh di ...
# 4     Pulang udah H-4 lebaran dilema sekali. Seperti tidak bisa melakukan apa2 dirumah sebelum lebaran. Buka puasa bareng cuman 3 hari sama ke...
# ...                                                                                                                                           ...
# 3284                                                           nah diam lebih bagus yaudah saya diam saja deh -_- kepo deh memang tadi kemna haha
# 3285  Tahukah kamu, bahwa saat itu papa memejamkan matanya dan menahan gejolak dan batinnya. Bahwa papa sangat ingin mengikuti keinginanmu tap...
# 3286  Sulitnya menetapkan Calon Wapresnya Jokowi di Pilpres 2019 salah satunya disebabkan gemuknya partai koalisi yang mengusung petahana. Seh...
# 3287  [USERNAME] dulu beneran ada mahasiswa Teknik UI nembak pacarnya pas sahur di Kukusan Teknik Depok, diliput kru Katakan Cinta (dan belum ...
# 3288                                                       Ya Allah, hanya Engkau yang mengetahui rasa sakit di hati ini. Sembuhkanlah Ya Allah..
#
#      sentiment
# 0          pos
# 1          pos
# 2          pos
# 3          neg
# 4          neg
# ...        ...
# 3284       neg
# 3285       pos
# 3286       neg
# 3287       pos
# 3288       neg
#
# [3289 rows x 3 columns]

# %%
# dataCleaned['tweet'] = dataCleaned['tweet'].parallel_apply(replace_with_tag)
# dataCleaned
# Out:
#         label  \
# 0       happy
# 1       happy
# 2       happy
# 3     sadness
# 4     sadness
# ...       ...
# 3284  sadness
# 3285     love
# 3286     fear
# 3287    happy
# 3288  sadness
#
#                                                                                                                                             tweet  \
# 0                                 pengin gudeg mbarek bu hj amat foto dari google sengaja biar teman teman juga membayangkannya berbagi itu indah
# 1     sharing pengalaman saja kemarin jam batalin tiket di stasiun pasar senen lancar antrian [not] terlalu rame menitan dan beress semua mung...
# 2     sharing sama teman tuh memang guna banget disaat lu merasa masalah lu berat banget ternyata teman kita sendiri punya masalah lebih berat...
# 3     orang lain kalau pakai ponco itu buat jas hujan nah dia pakai buat kasur ya tadi gara-gara saking enggak punya apa-apa mamak bilang kami...
# 4     pulang sudah h lebaran dilema sekali seperti [not] bisa melakukan apa-apa dirumah se [not] lebaran buka puasa bareng cuman hari sama kel...
# ...                                                                                                                                           ...
# 3284                                                               nah diam lebih bagus yaudah saya diam saja deh kepo deh memang tadi kemna haha
# 3285  tahukah kamu bahwa saat itu papa memejamkan matanya dan menahan gejolak dan batinnya bahwa papa sangat ingin mengikuti keinginanmu tapu ...
# 3286  sulitnya menetapkan calon wapresnya jokowi di pilpres salah satunya disebabkan gemuknya partai koalisi yang mengusung petahana sehingga ...
# 3287  [username] dulu benaran ada mahasiswa teknik ui menembak pacarnya pas sahur di kukusan teknik depok diliput kru katakan cinta dan [not] ...
# 3288                                                           ya allah hanya engkau yang mengetahui rasa sakit di hati ini sembuhkanlah ya allah
#
#      sentiment
# 0          pos
# 1          pos
# 2          pos
# 3          neg
# 4          neg
# ...        ...
# 3284       neg
# 3285       pos
# 3286       neg
# 3287       pos
# 3288       neg
#
# [3289 rows x 3 columns]

# %%
# for tag in tags:
#     print("{}: {}".format(tag, " ".join(dataCleaned.tweet.to_list()).count(tag)))
# Out:
# [neg]: 161
# [pos]: 148
# [url]: 447
# [username]: 958
# [not]: 1797

# %%
# dataCleaned.to_csv("cleanedData/dataCleaned.csv", index=False)

# %%
# re.findall(pos_emot, dataCleaned.tweet.to_string())
# Out:
# [('xo', '', '')]

# %%
import random
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,4),
                                              preprocessor=replace_with_tag)),
                    ('clf', MultinomialNB(alpha=1e-3))])

tweet = dataCleaned['tweet'].values
sent = dataCleaned['sentiment'].values

X_train, X_test, y_train, y_test = train_test_split(tweet, sent, test_size=0.1, random_state=random.randint(1, 10000))

# %%
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(ngram_range=(1, 4),
#                                  preprocessor=<function replace_with_tag at 0x7f819c4fdd30>)),
#                 ('clf', MultinomialNB(alpha=0.001))])

# %%
text_clf.score(X_test, y_test)
# Out:
# 0.7750759878419453

# %%
text_clf.predict(["syukur"])
# Out:
# array(['pos'], dtype='<U3')

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt
wordcloud = WordCloud(width = 800, height = 800, 
                      background_color ='white',
                      min_font_size = 10).generate(' '.join(X_train)) 

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
